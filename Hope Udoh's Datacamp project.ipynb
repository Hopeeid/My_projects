# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# importing the libraries needed
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete");
# Out:
# Setup Complete

# %%
# reading the dataset
chocolate = pd.read_csv('chocolate_bars.csv')
chocolate
# Out:
#         id manufacturer company_location  year_reviewed         bean_origin  \
# 0     2454         5150           U.S.A.           2019            Tanzania
# 1     2458         5150           U.S.A.           2019  Dominican Republic
# 2     2454         5150           U.S.A.           2019          Madagascar
# 3     2542         5150           U.S.A.           2021                Fiji
# 4     2546         5150           U.S.A.           2021           Venezuela
# ...    ...          ...              ...            ...                 ...
# 2525  1205       Zotter          Austria           2014               Blend
# 2526  1996       Zotter          Austria           2017            Colombia
# 2527  2036       Zotter          Austria           2018               Blend
# 2528  2170       Zotter          Austria           2018               Congo
# 2529  2170       Zotter          Austria           2018              Belize
#
# ...

# %%
# checking the info
chocolate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2530 entries, 0 to 2529
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                2530 non-null   int64
#  1   manufacturer      2530 non-null   object
#  2   company_location  2530 non-null   object
#  3   year_reviewed     2530 non-null   int64
#  4   bean_origin       2530 non-null   object
#  5   bar_name          2530 non-null   object
#  6   cocoa_percent     2530 non-null   float64
#  7   num_ingredients   2443 non-null   float64
#  8   ingredients       2443 non-null   object
#  9   review            2530 non-null   object
#  10  rating            2530 non-null   float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 158.2+ KB

# %%
# checking the manufacturer column 
chocolate.manufacturer
# Out:
# 0         5150
# 1         5150
# 2         5150
# 3         5150
# 4         5150
#          ...
# 2525    Zotter
# 2526    Zotter
# 2527    Zotter
# 2528    Zotter
# 2529    Zotter
# Name: manufacturer, Length: 2530, dtype: object

# %%
# checking the year reviewed column
chocolate['year_reviewed']
# Out:
# 0       2019
# 1       2019
# 2       2019
# 3       2021
# 4       2021
#         ...
# 2525    2014
# 2526    2017
# 2527    2018
# 2528    2018
# 2529    2018
# Name: year_reviewed, Length: 2530, dtype: int64

# %%
# checking for null values
chocolate.isna()
# Out:
#          id  manufacturer  company_location  year_reviewed  bean_origin  \
# 0     False         False             False          False        False
# 1     False         False             False          False        False
# 2     False         False             False          False        False
# 3     False         False             False          False        False
# 4     False         False             False          False        False
# ...     ...           ...               ...            ...          ...
# 2525  False         False             False          False        False
# 2526  False         False             False          False        False
# 2527  False         False             False          False        False
# 2528  False         False             False          False        False
# 2529  False         False             False          False        False
#
#       bar_name  cocoa_percent  num_ingredients  ingredients  review  rating
# ...

# %%
# checking for the sum of null values
chocolate.isnull().sum()
# Out:
# id                   0
# manufacturer         0
# company_location     0
# year_reviewed        0
# bean_origin          0
# bar_name             0
# cocoa_percent        0
# num_ingredients     87
# ingredients         87
# review               0
# rating               0
# dtype: int64

# %%
# to fill missing values, the mean is most representative and appropriate
chocolate.num_ingredients.mean()
# Out:
# 3.0413426115431847

# %%
# filling the missing values in the ingredients column with the mean
chocolate_1 = chocolate.num_ingredients.fillna(value = 3.0, inplace = True)
chocolate_1

# %%
# checking for the ingredients with the most frequent components
chocolate.ingredients.mode()
# Out:
# 0    B,S,C
# Name: ingredients, dtype: object

# %%
# in this case, with a string datatype, the mode is the most representative to fill the missing values
chocolate["ingredients"].fillna(value = "B,S,C", inplace = True)

# %%
# to check the columns
chocolate.columns
# Out:
# Index(['id', 'manufacturer', 'company_location', 'year_reviewed',
#        'bean_origin', 'bar_name', 'cocoa_percent', 'num_ingredients',
#        'ingredients', 'review', 'rating'],
#       dtype='object')

# %%
chocolate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2530 entries, 0 to 2529
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                2530 non-null   int64
#  1   manufacturer      2530 non-null   object
#  2   company_location  2530 non-null   object
#  3   year_reviewed     2530 non-null   int64
#  4   bean_origin       2530 non-null   object
#  5   bar_name          2530 non-null   object
#  6   cocoa_percent     2530 non-null   float64
#  7   num_ingredients   2530 non-null   float64
#  8   ingredients       2530 non-null   object
#  9   review            2530 non-null   object
#  10  rating            2530 non-null   float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 158.2+ KB

# %% [markdown]
# #### 1. What is the average rating by country of origin?

# %%
# to see all the columns
chocolate.columns
# Out:
# Index(['id', 'manufacturer', 'company_location', 'year_reviewed',
#        'bean_origin', 'bar_name', 'cocoa_percent', 'num_ingredients',
#        'ingredients', 'review', 'rating'],
#       dtype='object')

# %%
# to find the average rating by using the groupby function
avg_rating = chocolate.groupby('bean_origin', as_index = False)[['rating']].mean().sort_values(by='rating',ascending=False)
avg_rating
# Out:
#               bean_origin    rating
# 54                 Tobago  3.625000
# 7                   China  3.500000
# 42    Sao Tome & Principe  3.500000
# 44        Solomon Islands  3.450000
# 9                   Congo  3.318182
# ..                    ...       ...
# 43           Sierra Leone  2.750000
# 47  St.Vincent-Grenadines  2.750000
# 38               Principe  2.750000
# 30             Martinique  2.750000
# 39            Puerto Rico  2.714286
#
# [62 rows x 2 columns]

# %% [markdown]
# #### Question 2. How many bars were reviewed for each of those countries?

# %%
review_i = chocolate.groupby("bean_origin", as_index = False)[["review"]].count().sort_values(by='review',ascending=False)
review_i
# Out:
#               bean_origin  review
# 60              Venezuela     253
# 36                   Peru     244
# 13     Dominican Republic     226
# 14                Ecuador     219
# 28             Madagascar     177
# ..                    ...     ...
# 50               Suriname       1
# 49                Sumatra       1
# 48               Sulawesi       1
# 47  St.Vincent-Grenadines       1
# 38               Principe       1
#
# [62 rows x 2 columns]

# %% [markdown]
# #### 3. Create plots to visualize findings for questions 1 and 2.

# %%
plt.figure(figsize = (20, 5))
sns.barplot(x = "bean_origin", y = "rating", data = avg_rating[:15])
plt.xticks(rotation = 90);

# %%
plt.figure(figsize = (20, 5))
sns.barplot(x = "bean_origin", y = "rating", data = avg_rating[48:])
plt.xticks(rotation = 90);

# %% [markdown]
# - The bean from Tobago has the highest ratings
# - The bean from Puerto Rico has the lowest ratings

# %%
# to visualize question 2
plt.figure(figsize = (20, 5))
sns.barplot(x = "bean_origin", y = "review", data = review_i)
plt.xticks(rotation = 90);

# %% [markdown]
# -From this chart it can be said that Venezuela has the most number of review

# %% [markdown]
# #### 4. Is the cacao bean's origin an indicator of quality?

# %%
# to check if the bean's origin is an indicator of quality, it would be evaluated based on the pattern 
#of rating/bean_origin chart and cocoa_content/rating chart
plt.figure(figsize=(20,5))
sns.lineplot(x='bean_origin', y='rating', data= chocolate)
plt.xticks(rotation=90);

# %%
plt.figure(figsize=(20,5))
sns.lineplot(x='cocoa_percent', y='rating', data= chocolate)
plt.xticks(rotation=90);

# %% [markdown]
# - From both charts, it can be said that there is no similar pattern between the charts.-
# - it can also be said that cocao bean origin does not indicate quality

# %% [markdown]
# #### Question 4
# - How does cocoa content relate to rating? What is the average cocoa content for bars with higher ratings (above 3.5)?

# %%
# to check the relationship between cocoa content and rating
plt.figure(figsize=(20,5))
sns.barplot(x='cocoa_percent', y='rating', data=chocolate)
plt.xticks(rotation=90);

# %% [markdown]
# - From the above barplot, it is observed that there is no relationship between Cocoa percent and rating.
# - 50% cocoa content has the highest rating above 3.5, and 63% cocoa content has a rating of 3.5
# - There is no clear pattern indicating realationship between cocoa percent and rating.

# %%
#What is the average cocoa content for bars with higher ratings (above 3.5)?
high_rating=chocolate.loc[chocolate.rating>3.5]
aver_cocoa_cont = high_rating.cocoa_percent.mean()
aver_cocoa_cont
# Out:
# 70.94781553398059

# %% [markdown]
# - The average cocoa content  for bars with higher rating is approximately 71%

# %% [markdown]
# #### 6. Your research indicates that some consumers want to avoid bars with lecithin. Compare the average rating of bars with and without lecithin (L in the ingredients).

# %%
chocolate.ingredients.unique()
# Out:
# array(['B,S,C', 'B,S,C,L', 'B,S', 'B,S,C,V', 'B,S,C,V,L', 'B,S,C,V,L,Sa',
#        'B,S,C,V,Sa', 'B,S,V,L', 'B,S*', 'B', 'B,S*,C', 'B,S,L', 'B,S,V',
#        'B,S*,C,L', 'B,S*,C,Sa', 'B,S*,Sa', 'B,S,C,Sa', 'B,S*,V,L', 'B,C',
#        'B,S*,C,V', 'B,S,C,L,Sa'], dtype=object)

# %%
choc_bar_drna = read_file.dropna()
avg_rating_with_lec = choc_bar_drna[choc_bar_drna["ingredients"].str.contains("L")].rating.mean()
avg_rating_without_lec = choc_bar_drna[~choc_bar_drna["ingredients"].str.contains("L")].rating.mean()
print("Average rating with lecithin "+str(avg_rating_with_lec))
print("Average rating without lecithin "+str(avg_rating_without_lec))

# %%
l_ingredients = chocolate[chocolate.ingredients.str.contains('L')].rating.mean()
l_ingredients
print('The average rating with lecithin is', str(l_ingredients))
# Out:
# The average rating with lecithin is 3.150608519269777

# %%
not_l_ingredients = chocolate[~chocolate.ingredients.str.contains('L')].rating.mean()
not_l_ingredients
print('The average rating without lecithin is', str(not_l_ingredients))
# Out:
# The average rating without lecithin is 3.2074128620520375

# %% [markdown]
# - From this findings, chocolate bars with Lecithin have the average rating of 3.15. While those with no Lecithin have the average of rating 3.20

# %% [markdown]
# #### Summary
# - In summary, the bean origin of the chocolate has no relationship with the rating. Rating is based on quality and not the origin.
# - The bean from Tobago has the highest ratings, while the bean from Puerto Rico has the lowest ratings
# - It can be said that Venezuela has the most number of review.
# - 50% cocoa content has the highest rating above 3.5, and 63% cocoa content has a rating of 3.5
# - There is no clear pattern indicating realationship between cocoa percent and rating.
# - The average cocoa content for bars with higher rating is approximately 71%
# - Chocolate bars with Lecithin have the average rating of 3.15. While those with no Lecithin have the average of rating 3.20
# - It can also be said that cocoa bean origin does not indicate quality
